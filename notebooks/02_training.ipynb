# %% [markdown]
# # Heart Disease — Training Walkthrough
#
# Wraps `src.train` so you can iterate interactively. The persisted model is identical to the CI artifact.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

from src.train import main as train_main
train_main()

# %%
import json, pathlib
metrics = json.loads(pathlib.Path('../reports/metrics.json').read_text())
metrics

# %%
from src.inference import load_model, predict_one, SAMPLE
predict_one(load_model(), SAMPLE)
